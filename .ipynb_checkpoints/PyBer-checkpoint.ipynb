# %%
#Add Matplotlib inline magic command
# %matplotlib inline

#Dependencies and Setup
import matplotlib.pyplot as plt
import pandas as pd

# %%
#File to load
city_data_to_load = "Resources/city_data.csv"
ride_data_to_load = "Resources/ride_data.csv"

# %%
#Read the city data file and store it in a pandas DataFrame
city_data_df = pd.read_csv(city_data_to_load)
city_data_df.head(10)
# Out:
#             city  driver_count   type
# 0    Richardfort            38  Urban
# 1   Williamsstad            59  Urban
# 2    Port Angela            67  Urban
# 3     Rodneyfort            34  Urban
# 4    West Robert            39  Urban
# 5   West Anthony            70  Urban
# 6    West Angela            48  Urban
# 7  Martinezhaven            25  Urban
# 8      Karenberg            22  Urban
# 9    Barajasview            26  Urban

# %%
#Read the rode data file and store it in a pandas DataFrame
ride_data_df = pd.read_csv(ride_data_to_load)
ride_data_df.head(10)
# Out:
#                  city                 date   fare        ride_id
# 0  Lake Jonathanshire  2019-01-14 10:14:22  13.83  5739410935873
# 1  South Michelleport  2019-03-04 18:24:09  30.24  2343912425577
# 2  Port Samanthamouth  2019-02-24 04:29:00  33.44  2005065760003
# 3          Rodneyfort  2019-02-10 23:22:03  23.44  5149245426178
# 4          South Jack  2019-03-06 04:28:35  34.58  3908451377344
# 5        South Latoya  2019-03-11 12:26:48   9.52  1994999424437
# 6       New Paulville  2019-02-27 11:17:56  43.25   793208410091
# 7        Simpsonburgh  2019-04-26 00:43:24  35.98   111953927754
# 8     South Karenland  2019-01-08 03:28:48  35.09  7995623208694
# 9       North Jasmine  2019-03-09 06:26:29  42.81  5327642267789

# %%
#Inspect the city df
#Get the columns and the rows that are not null
city_data_df.count()
# Out:
# city            120
# driver_count    120
# type            120
# dtype: int64

# %%
#Get the columns and the rows that are not null
city_data_df.isnull().sum()
# Out:
# city            0
# driver_count    0
# type            0
# dtype: int64

# %%
#Get the data types of each column
city_data_df.dtypes
# Out:
# city            object
# driver_count     int64
# type            object
# dtype: object

# %%
#Get the unique values of the type of city
city_data_df["type"].unique()
# Out:
# array(['Urban', 'Suburban', 'Rural'], dtype=object)

# %%
#Get the number of data points from the Urban cities.
sum(city_data_df["type"]=="Urban")
# Out:
# 66

# %%
#Get the number of data points from the Suburabn cities.
sum(city_data_df["type"]=="Suburban")
# Out:
# 36

# %%
#Get the number of data points from the Suburabn cities.
sum(city_data_df["type"]=="Rural")
# Out:
# 18

# %%
#Inspect the ride df
#Get the columns and the rows that are not null
ride_data_df.count()
# Out:
# city       2375
# date       2375
# fare       2375
# ride_id    2375
# dtype: int64

# %%
#Get the columns and the rows that are not null
ride_data_df.isnull().sum()
# Out:
# city       0
# date       0
# fare       0
# ride_id    0
# dtype: int64

# %%
#Get the data types of each column
ride_data_df.dtypes
# Out:
# city        object
# date        object
# fare       float64
# ride_id      int64
# dtype: object

# %%
#Combine the data into a single dataset
pyber_data_df = pd.merge(ride_data_df, city_data_df, how="left", on=["city", "city"])

# Display the DataFrame
pyber_data_df.head()
# Out:
#                  city                 date   fare        ride_id  \
# 0  Lake Jonathanshire  2019-01-14 10:14:22  13.83  5739410935873
# 1  South Michelleport  2019-03-04 18:24:09  30.24  2343912425577
# 2  Port Samanthamouth  2019-02-24 04:29:00  33.44  2005065760003
# 3          Rodneyfort  2019-02-10 23:22:03  23.44  5149245426178
# 4          South Jack  2019-03-06 04:28:35  34.58  3908451377344
#
#    driver_count   type
# 0             5  Urban
# 1            72  Urban
# 2            57  Urban
# 3            34  Urban
# 4            46  Urban

# %%
#Create the Urban city DataFrame
urban_cities_df = pyber_data_df[pyber_data_df["type"] == "Urban"]
urban_cities_df.head()
# Out:
#                  city                 date   fare        ride_id  \
# 0  Lake Jonathanshire  2019-01-14 10:14:22  13.83  5739410935873
# 1  South Michelleport  2019-03-04 18:24:09  30.24  2343912425577
# 2  Port Samanthamouth  2019-02-24 04:29:00  33.44  2005065760003
# 3          Rodneyfort  2019-02-10 23:22:03  23.44  5149245426178
# 4          South Jack  2019-03-06 04:28:35  34.58  3908451377344
#
#    driver_count   type
# 0             5  Urban
# 1            72  Urban
# 2            57  Urban
# 3            34  Urban
# 4            46  Urban

# %%
#Create the Suburban and Rural city DataFrames
suburban_cities_df = pyber_data_df[pyber_data_df["type"] == "Suburban"]
rural_cities_df = pyber_data_df[pyber_data_df["type"] == "Rural"]

# %%
#Get the number of rides for urban cities.
urban_ride_count = urban_cities_df.groupby(["city"]).count()["ride_id"]
urban_ride_count.head()
# Out:
# city
# Amandaburgh        18
# Barajasview        22
# Carriemouth        27
# Christopherfurt    27
# Deanville          19
# Name: ride_id, dtype: int64

# %%
#Create the suburban and rural ride count
suburban_ride_count = suburban_cities_df.groupby(["city"]).count()["ride_id"]
rural_ride_count = rural_cities_df.groupby(["city"]).count()["ride_id"]

# %%
#Get average fare for each city in the urban cities
urban_avg_fare = urban_cities_df.groupby(["city"]).mean()["fare"]
urban_avg_fare.head()
# Out:
# city
# Amandaburgh        24.641667
# Barajasview        25.332273
# Carriemouth        28.314444
# Christopherfurt    24.501852
# Deanville          25.842632
# Name: fare, dtype: float64

# %%
#Get average fare for each city in the suburban and rural cities
suburban_avg_fare = suburban_cities_df.groupby(["city"]).mean()["fare"]
rural_avg_fare = rural_cities_df.groupby(["city"]).mean()["fare"]

# %%
#Get the average number of drivers for each urban city.
urban_driver_count = urban_cities_df.groupby(["city"]).mean()["driver_count"]
urban_driver_count.head()
# Out:
# city
# Amandaburgh        12.0
# Barajasview        26.0
# Carriemouth        52.0
# Christopherfurt    41.0
# Deanville          49.0
# Name: driver_count, dtype: float64

# %%
#Get the average number of drivers for each city for the suburban and rural cities.
suburban_driver_count = suburban_cities_df.groupby(["city"]).mean()["driver_count"]
rural_driver_count = rural_cities_df.groupby(["city"]).mean()["driver_count"]

# %%
#Build the scatter plots for urban citie
plt.scatter(urban_ride_count, urban_avg_fare)

# %%
#Build the scatter plots for urban cities
plt.scatter(urban_ride_count,
    urban_avg_fare,
    s=urban_driver_count)

# %%
#Build the scatter plots for urban cities
#Increase the size by a factor of 10, add a black edge color and a line width of 1, make markers coral and 20% transparent
#Add a title, labels for the axes, a legend, and a grid.
plt.scatter(urban_ride_count,
    urban_avg_fare,
    s=urban_driver_count *10, c="coral",
    edgecolor="black", linewidth=1,
    alpha=0.8, label="Urban")

plt.title("Pyber Ride-Sharing Data(2019)")
plt.xlabel("Total Number of Rides (Per City)")
plt.ylabel("Average Fare ($)")
plt.grid(True)

#Add the legend
plt.legend()

# %%
#Build the scatter plots for suburban cities
#Increase the size by a factor of 10, add a black edge color and a line width of 1, make markers coral and 20% transparent
#Add a title, labels for the axes, a legend, and a grid.
plt.scatter(suburban_ride_count,
    suburban_avg_fare,
    s=suburban_driver_count *10, c="skyblue",
    edgecolor="black", linewidth=1,
    alpha=0.8, label="Suburban")

plt.title("Pyber Ride-Sharing Data(2019)")
plt.xlabel("Total Number of Rides (Per City)")
plt.ylabel("Average Fare ($)")
plt.grid(True)

#Add the legend
plt.legend()

# %%
#Build the scatter plots for rural cities
#Increase the size by a factor of 10, add a black edge color and a line width of 1, make markers coral and 20% transparent
#Add a title, labels for the axes, a legend, and a grid.
plt.scatter(rural_ride_count,
    rural_avg_fare, s=rural_driver_count*10, c="gold",
    edgecolor="black", linewidth=1,
    alpha=0.8, label="Rural")

plt.title("Pyber Ride-Sharing Data(2019)")
plt.xlabel("Total Number of Rides (Per City)")
plt.ylabel("Average Fare ($)")
plt.grid(True)

#Add the legend
plt.legend()

# %%
#Add the scatter charts for each type of city

plt.scatter(urban_ride_count,
    urban_avg_fare,
    s=urban_driver_count *10, c="coral",
    edgecolor="black", linewidth=1,
    alpha=0.8, label="Urban")

plt.scatter(suburban_ride_count,
    suburban_avg_fare,
    s=suburban_driver_count *10, c="skyblue",
    edgecolor="black", linewidth=1,
    alpha=0.8, label="Suburban")

plt.scatter(rural_ride_count,
    rural_avg_fare, s=rural_driver_count*10, c="gold",
    edgecolor="black", linewidth=1,
    alpha=0.8, label="Rural")

# Show the plot
plt.show()

# %%
#Build the scatter charts for each city type.
plt.subplots(figsize=(10, 6))

plt.scatter(urban_ride_count,
    urban_avg_fare,
    s=urban_driver_count *10, c="coral",
    edgecolor="black", linewidth=1,
    alpha=0.8, label="Urban")

plt.scatter(suburban_ride_count,
    suburban_avg_fare,
    s=suburban_driver_count *10, c="skyblue",
    edgecolor="black", linewidth=1,
    alpha=0.8, label="Suburban")

plt.scatter(rural_ride_count,
    rural_avg_fare, s=rural_driver_count*10, c="gold",
    edgecolor="black", linewidth=1,
    alpha=0.8, label="Rural")

#Incorporate the other graph properties
plt.title("Pyber Ride-Sharing Data(2019)", fontsize=20)
plt.ylabel("Average Fare ($)", fontsize=12)
plt.xlabel("Total Number of Rides (Per City)", fontsize=12)
plt.grid(True)

#Add the legend
plt.legend()

# Show the plot
plt.show()

# %%
#Build the scatter charts for each city type.
plt.subplots(figsize=(10, 6))

plt.scatter(urban_ride_count,
    urban_avg_fare,
    s=urban_driver_count *10, c="coral",
    edgecolor="black", linewidth=1,
    alpha=0.8, label="Urban")

plt.scatter(suburban_ride_count,
    suburban_avg_fare,
    s=suburban_driver_count *10, c="skyblue",
    edgecolor="black", linewidth=1,
    alpha=0.8, label="Suburban")

plt.scatter(rural_ride_count,
    rural_avg_fare, s=rural_driver_count*10, c="gold",
    edgecolor="black", linewidth=1,
    alpha=0.8, label="Rural")

#Incorporate the other graph properties
plt.title("Pyber Ride-Sharing Data(2019)", fontsize=20)
plt.ylabel("Average Fare ($)", fontsize=12)
plt.xlabel("Total Number of Rides (Per City)", fontsize=12)
plt.grid(True)

#Create a legend
lgnd = plt.legend(fontsize="12", mode="Expanded",
          scatterpoints=1, loc="best", title="City Types")

lgnd.legendHandles[0]._sizes = [75]
lgnd.legendHandles[1]._sizes = [75]
lgnd.legendHandles[2]._sizes = [75]

#Incorporate a text label about circle size.
plt.text(42, 35, "Note: Circle size correlates with driver count per city.", fontsize="12")

# Save the figure
plt.savefig("analysis/Fig1.png")

#Show the plot
plt.show()

# %%
#Get summary statistics
urban_ride_count.describe()
# Out:
# count    66.000000
# mean     24.621212
# std       5.408726
# min      12.000000
# 25%      21.000000
# 50%      24.000000
# 75%      28.000000
# max      39.000000
# Name: ride_id, dtype: float64

# %%
suburban_ride_count.describe()
# Out:
# count    36.000000
# mean     17.361111
# std       4.323707
# min       9.000000
# 25%      14.000000
# 50%      17.000000
# 75%      19.250000
# max      27.000000
# Name: ride_id, dtype: float64

# %%
rural_ride_count.describe()
# Out:
# count    18.000000
# mean      6.944444
# std       2.508157
# min       3.000000
# 25%       5.250000
# 50%       6.000000
# 75%       8.750000
# max      12.000000
# Name: ride_id, dtype: float64

# %%
#Calculate the mean of the ride count for each city type.
round(urban_ride_count.mean(),2), round(suburban_ride_count.mean(),2), round(rural_ride_count.mean(),2)
# Out:
# (24.62, 17.36, 6.94)

# %%
#Calculate the median for the number or rides in the urban cities
urban_ride_count.median()
# Out:
# 24.0

# %%
# Calculate the mode of the ride count for the urban cities.
urban_ride_count.mode()
# Out:
# 0    22
# 1    25
# dtype: int64

# %%
# Calculate the mode of the ride count for the suburban cities.
suburban_ride_count.mode()
# Out:
# 0    17
# dtype: int64

# %%
# Calculate the mode of the ride count for the rural cities.
rural_ride_count.mode()
# Out:
# 0    6
# dtype: int64

# %%
# Import NumPy and the stats module from SciPy.
import numpy as np
import scipy.stats as sts

# %%
# Calculate the measures of central tendency for the ride count for the urban cities.
mean_urban_ride_count = np.mean(urban_ride_count)
print(f"The mean for the urban ride counts for urban trips is {mean_urban_ride_count:.2f}.")

median_urban_ride_count = np.median(urban_ride_count)
print(f"The median for the urban ride counts for urban trips is {median_urban_ride_count}.")

mode_urban_ride_count = sts.mode(urban_ride_count)
print(f"The mode for the urban ride counts for urban trips is {mode_urban_ride_count}.")
# Out:
# The mean for the urban ride counts for urban trips is 24.62.
# The median for the urban ride counts for urban trips is 24.0.
# The mode for the urban ride counts for urban trips is ModeResult(mode=array([22], dtype=int64), count=array([7])).

# %%
# Calculate the measures of central tendency for the ride count for the suburban cities.
mean_suburban_ride_count = np.mean(suburban_ride_count)
print(f"The mean for the suburban ride counts for suburban trips is {mean_suburban_ride_count:.2f}.")

median_suburban_ride_count = np.median(suburban_ride_count)
print(f"The median for the suburban ride counts for suburban trips is {median_suburban_ride_count}.")

mode_suburban_ride_count = sts.mode(suburban_ride_count)
print(f"The mode for the suburban ride counts for suburban trips is {mode_suburban_ride_count}.")
# Out:
# The mean for the suburban ride counts for suburban trips is 17.36.
# The median for the suburban ride counts for suburban trips is 17.0.
# The mode for the suburban ride counts for suburban trips is ModeResult(mode=array([17], dtype=int64), count=array([7])).

# %%
# Calculate the measures of central tendency for the ride count for the rural cities.
mean_rural_ride_count = np.mean(rural_ride_count)
print(f"The mean for the rural ride counts for rural trips is {mean_rural_ride_count:.2f}.")

median_rural_ride_count = np.median(rural_ride_count)
print(f"The median for the rural ride counts for rural trips is {median_rural_ride_count}.")

mode_rural_ride_count = sts.mode(rural_ride_count)
print(f"The mode for the rural ride counts for rural trips is {mode_rural_ride_count}.")
# Out:
# The mean for the rural ride counts for rural trips is 6.94.
# The median for the rural ride counts for rural trips is 6.0.
# The mode for the rural ride counts for rural trips is ModeResult(mode=array([6], dtype=int64), count=array([5])).

# %%
#5.4.2
#Get the fares for the urban cities
urban_fares = urban_cities_df["fare"]
urban_fares.head()
# Out:
# 0    13.83
# 1    30.24
# 2    33.44
# 3    23.44
# 4    34.58
# Name: fare, dtype: float64

# %%
#Calculate the measures of central tendency for the average fare for the urban cities
mean_urban_fares = np.mean(urban_fares)
print(f"The mean fare price for the urban trips is {mean_urban_fares:.2f}.")

median_urban_fares = np.median(urban_fares)
print(f"The median fare price for urban trips is {median_urban_fares}.")

mode_urban_fares = sts.mode(urban_fares)
print(f"The mode fare price for urban trips is {mode_urban_fares}.")
# Out:
# The mean fare price for the urban trips is 24.53.
# The median fare price for urban trips is 24.64.
# The mode fare price for urban trips is ModeResult(mode=array([22.86]), count=array([5])).

# %%
#Get the fares for the suburban cities
suburban_fares = suburban_cities_df["fare"]
suburban_fares.head()
# Out:
# 1625    27.79
# 1626    18.75
# 1627    21.71
# 1628    17.10
# 1629    37.78
# Name: fare, dtype: float64

# %%
#Calculate the measures of central tendency for the average fare for the suburban cities
mean_suburban_fares = np.mean(suburban_fares)
print(f"The mean fare price for the suburban trips is {mean_suburban_fares:.2f}.")

median_suburban_fares = np.median(suburban_fares)
print(f"The median fare price for suburban trips is {median_suburban_fares}.")

mode_suburban_fares = sts.mode(suburban_fares)
print(f"The mode fare price for suburban trips is {mode_suburban_fares}.")
# Out:
# The mean fare price for the suburban trips is 30.97.
# The median fare price for suburban trips is 30.75.
# The mode fare price for suburban trips is ModeResult(mode=array([17.99]), count=array([3])).

# %%
#Get the fares for the suburban cities
rural_fares = rural_cities_df["fare"]
rural_fares.head()
# Out:
# 2250    43.22
# 2251    12.42
# 2252    54.85
# 2253    47.90
# 2254    51.80
# Name: fare, dtype: float64

# %%
#Calculate the measures of central tendency for the average fare for the rural cities
mean_rural_fares = np.mean(rural_fares)
print(f"The mean fare price for the rural trips is {mean_rural_fares:.2f}.")

median_rural_fares = np.median(rural_fares)
print(f"The median fare price for rural trips is {median_rural_fares}.")

mode_rural_fares = sts.mode(rural_fares)
print(f"The mode fare price for rural trips is {mode_rural_fares}.")
# Out:
# The mean fare price for the rural trips is 34.62.
# The median fare price for rural trips is 37.05.
# The mode fare price for rural trips is ModeResult(mode=array([37.05]), count=array([2])).

# %%
#5.4.3
# Get the driver count data from the urban cities
urban_drivers = urban_cities_df['driver_count']
urban_drivers.head()
# Out:
# 0     5
# 1    72
# 2    57
# 3    34
# 4    46
# Name: driver_count, dtype: int64

# %%
#Calculate the measures of central tendency for the average driver count for the urban cities
mean_urban_driver_count = np.mean(urban_driver_count)
print(f"The mean driver count for the urban trips is {mean_urban_driver_count:.2f}.")

median_urban_driver_count = np.median(urban_driver_count)
print(f"The median driver count for urban trips is {median_urban_driver_count}.")

mode_urban_driver_count = sts.mode(urban_driver_count)
print(f"The mode driver count for urban trips is {mode_urban_driver_count}.")
# Out:
# The mean driver count for the urban trips is 36.44.
# The median driver count for urban trips is 37.0.
# The mode driver count for urban trips is ModeResult(mode=array([25.]), count=array([4])).

# %%
# Get the driver count data from the suburban cities
suburban_drivers = suburban_cities_df['driver_count']
suburban_drivers.head()
# Out:
# 1625    11
# 1626    20
# 1627    22
# 1628    19
# 1629    12
# Name: driver_count, dtype: int64

# %%
#Calculate the measures of central tendency for the average driver count for the suburban cities
mean_suburban_driver_count = np.mean(suburban_driver_count)
print(f"The mean driver count for the suburban trips is {mean_suburban_driver_count:.2f}.")

median_suburban_driver_count = np.median(suburban_driver_count)
print(f"The median driver count for suburban trips is {median_suburban_driver_count}.")

mode_suburban_driver_count = sts.mode(suburban_driver_count)
print(f"The mode driver count for suburban trips is {mode_suburban_driver_count}.")
# Out:
# The mean driver count for the suburban trips is 13.61.
# The median driver count for suburban trips is 15.0.
# The mode driver count for suburban trips is ModeResult(mode=array([20.]), count=array([5])).

# %%
# Get the driver count data from the rural cities
rural_drivers = rural_cities_df['driver_count']
rural_drivers.head()
# Out:
# 2250    9
# 2251    8
# 2252    6
# 2253    2
# 2254    2
# Name: driver_count, dtype: int64

# %%
#Calculate the measures of central tendency for the average driver count for the rural cities
mean_rural_driver_count = np.mean(rural_driver_count)
print(f"The mean driver count for the rural trips is {mean_rural_driver_count:.2f}.")

median_rural_driver_count = np.median(rural_driver_count)
print(f"The median driver count for rural trips is {median_rural_driver_count}.")

mode_rural_driver_count = sts.mode(rural_driver_count)
print(f"The mode driver count for rural trips is {mode_rural_driver_count}.")
# Out:
# The mean driver count for the rural trips is 4.33.
# The median driver count for rural trips is 4.0.
# The mode driver count for rural trips is ModeResult(mode=array([1.]), count=array([5])).

# %%
#5.4.4
#Create a box-and-whisker plot for the urban cities ride count
x_labels = ["Urban"]
fig, ax = plt.subplots()
ax.boxplot(urban_ride_count, labels=x_labels)

#Add the title
ax.set_title("Ride Count Data (2019)")

#Add x and y axis labels
ax.set_ylabel("Number of Rides")

#Adjust ticks of y-axis
ax.set_yticks(np.arange(10, 41, step=2.0))

#Add the grid
ax.grid()

#Show the plot
plt.show()

# %%
#Skill drill
#Create a box-and-whisker plot for the suburban cities ride count
x_labels = ["Suburban"]
fig, ax = plt.subplots()
ax.boxplot(suburban_ride_count, labels=x_labels)

#Add the title
ax.set_title("Ride Count Data (2019)")

#Add x and y axis labels
ax.set_ylabel("Number of Rides")

#Adjust ticks of y-axis
ax.set_yticks(np.arange(6, 30, step=2.0))

#Add the grid
ax.grid()

#Show the plot
plt.show()

# %%
#Skill drill
#Create a box-and-whisker plot for the rural cities ride count
x_labels = ["Rural"]
fig, ax = plt.subplots()
ax.boxplot(rural_ride_count, labels=x_labels)

#Add the title
ax.set_title("Ride Count Data (2019)")

#Add x and y axis labels
ax.set_ylabel("Number of Rides")

#Adjust ticks of y-axis
ax.set_yticks(np.arange(2, 14, step=2.0))

#Add the grid
ax.grid()

#Show the plot
plt.show()

# %%
#Add all ride count box-and-whisker plots to the same graph
x_labels = ["Urban", "Suburban", "Rural"]
ride_count_data = [urban_ride_count, suburban_ride_count, rural_ride_count]
fig, ax = plt.subplots(figsize=(10, 6))

#Add the title
ax.set_title("Ride Count Data (2019)",fontsize=20)

#Add the labels for x & y-axis
ax.set_xlabel("City Types",fontsize=14)
ax.set_ylabel("Number of Rides", fontsize=14)
ax.boxplot(ride_count_data, labels=x_labels)

#Adjust the ticks of y-axis
ax.set_yticks(np.arange(0, 45, step=3.0))

#Add the grid
ax.grid()

# Save the figure
plt.savefig("analysis/Fig2.png")

plt.show()

# %%
#Get the city that matches 39.
urban_city_outlier = urban_ride_count[urban_ride_count==39].index[0]
print(f"{urban_city_outlier} has the highest rider count.")
# Out:
# West Angela has the highest rider count.

# %%
urban_ride_count[urban_ride_count==39]
# Out:
# city
# West Angela    39
# Name: ride_id, dtype: int64

# %%
#Box-and-Whisker plots for ride fare data
#Create a box-and-whisker plot for the urban fare data
x_labels = ["Urban"]
fig, ax = plt.subplots()
ax.boxplot(urban_fares, labels=x_labels)

#Add the title
ax.set_title("Ride Fare Data (2019)")

#Add x and y axis labels
ax.set_ylabel("Fare ($)")

#Adjust ticks of y-axis
ax.set_yticks(np.arange(0, 51, step=5.0))

#Add the grid
ax.grid()

#Show the plot
plt.show()

print("Summary Statistics")
urban_fares.describe()
# Out:
# Summary Statistics
# count    1625.000000
# mean       24.525772
# std        11.738649
# min         4.050000
# 25%        14.550000
# 50%        24.640000
# 75%        34.580000
# max        44.970000
# Name: fare, dtype: float64

# %%
#Skill drill
#Create a box-and-whisker plot for the suburban fare data
x_labels = ["Suburban"]
fig, ax = plt.subplots()
ax.boxplot(suburban_fares, labels=x_labels)

#Add the title
ax.set_title("Ride Fare Data (2019)")

#Add x and y axis labels
ax.set_ylabel("Fare ($)")

#Adjust ticks of y-axis
ax.set_yticks(np.arange(0, 51, step=5.0))

#Add the grid
ax.grid()

#Show the plot
plt.show()

print("Summary Statistics")
suburban_fares.describe()
# Out:
# Summary Statistics
# count    625.000000
# mean      30.970128
# std       10.677508
# min       12.050000
# 25%       21.970000
# 50%       30.750000
# 75%       39.830000
# max       49.960000
# Name: fare, dtype: float64

# %%
#Create a box-and-whisker plot for the rural fare data
x_labels = ["Rural"]
fig, ax = plt.subplots()
ax.boxplot(rural_fares, labels=x_labels)

#Add the title
ax.set_title("Ride Fare Data (2019)")

#Add x and y axis labels
ax.set_ylabel("Fare ($)")

#Adjust ticks of y-axis
ax.set_yticks(np.arange(0, 51, step=5.0))

#Add the grid
ax.grid()

#Show the plot
plt.show()

print("Summary Statistics")
rural_fares.describe()
# Out:
# Summary Statistics
# count    125.000000
# mean      34.623440
# std       14.558046
# min       10.110000
# 25%       19.900000
# 50%       37.050000
# 75%       47.070000
# max       58.550000
# Name: fare, dtype: float64

# %%
#Skill drill
#Create a box-and-whisker plot that has all three city types' fare data in one plot

#Add all fare data box-and-whisker plots to the same graph
x_labels = ["Urban", "Suburban", "Rural"]
fares_data = [urban_fares, suburban_fares, rural_fares]
fig, ax = plt.subplots(figsize=(10, 6))

#Add the title
ax.set_title("Ride Fare Data (2019)",fontsize=20)

#Add the labels for x & y-axis
ax.set_xlabel("City Types",fontsize=14)
ax.set_ylabel("Fares ($)", fontsize=14)
ax.boxplot(fares_data, labels=x_labels)

#Adjust the ticks of y-axis
ax.set_yticks(np.arange(0, 60, step=5.0))

#Add the grid
ax.grid()

# Save the figure
plt.savefig("analysis/Fig3.png")

plt.show()

# %%
#Box-and-Whisker plots for driver count data
#Create a box-and-whisker plot for the urban driver count data
x_labels = ["Urban"]
fig, ax = plt.subplots()
ax.boxplot(urban_driver_count, labels=x_labels)

#Add the title
ax.set_title("Driver Count Fare Data (2019)")

#Add x and y axis labels
ax.set_ylabel("Number of Driver")

#Adjust ticks of y-axis
ax.set_yticks(np.arange(0, 90, step=5.0))

#Add the grid
ax.grid()

#Show the plot
plt.show()

print("Summary Statistics")
urban_driver_count.describe()
# Out:
# Summary Statistics
# count    66.000000
# mean     36.439394
# std      19.827819
# min       3.000000
# 25%      22.000000
# 50%      37.000000
# 75%      49.750000
# max      73.000000
# Name: driver_count, dtype: float64

# %%
#Skill drill
#Create a box-and-whisker plot for the suburban driver count data
x_labels = ["Suburban"]
fig, ax = plt.subplots()
ax.boxplot(suburban_driver_count, labels=x_labels)

#Add the title
ax.set_title("Driver Count Fare Data (2019)")

#Add x and y axis labels
ax.set_ylabel("Number of Driver")

#Adjust ticks of y-axis
ax.set_yticks(np.arange(0, 90, step=5.0))

#Add the grid
ax.grid()

#Show the plot
plt.show()

print("Summary Statistics")
suburban_driver_count.describe()
# Out:
# Summary Statistics
# count    36.000000
# mean     13.611111
# std       8.022389
# min       1.000000
# 25%       6.500000
# 50%      15.000000
# 75%      20.250000
# max      25.000000
# Name: driver_count, dtype: float64

# %%
#Skill drill
#Create a box-and-whisker plot for the rural driver count data
x_labels = ["Rural"]
fig, ax = plt.subplots()
ax.boxplot(rural_driver_count, labels=x_labels)

#Add the title
ax.set_title("Driver Count Fare Data (2019)")

#Add x and y axis labels
ax.set_ylabel("Number of Driver")

#Adjust ticks of y-axis
ax.set_yticks(np.arange(0, 90, step=5.0))

#Add the grid
ax.grid()

#Show the plot
plt.show()

print("Summary Statistics")
rural_driver_count.describe()
# Out:
# Summary Statistics
# count    18.000000
# mean      4.333333
# std       2.828427
# min       1.000000
# 25%       1.250000
# 50%       4.000000
# 75%       7.000000
# max       9.000000
# Name: driver_count, dtype: float64

# %%
#Skill drill
#Create a box-and-whisker plot that has all three city types' driver count data in one box-and-whisker plot

#Add all driver count data box-and-whisker plots to the same graph
x_labels = ["Urban", "Suburban", "Rural"]
driver_count_data = [urban_driver_count, suburban_driver_count, rural_driver_count]
fig, ax = plt.subplots(figsize=(10, 6))

#Add the title
ax.set_title("Driver Count Data (2019)",fontsize=20)

#Add the labels for x & y-axis
ax.set_xlabel("City Types",fontsize=14)
ax.set_ylabel("Number of Driver", fontsize=14)
ax.boxplot(driver_count_data, labels=x_labels)

#Adjust the ticks of y-axis
ax.set_yticks(np.arange(0, 75, step=5.0))

#Add the grid
ax.grid()

# Save the figure
plt.savefig("analysis/Fig4.png")

plt.show()

# %%
#5.5.1

#Get the sum of the fares for each city type.
sum_fares_by_type = pyber_data_df.groupby(["type"]).sum()["fare"]
sum_fares_by_type
# Out:
# type
# Rural        4327.93
# Suburban    19356.33
# Urban       39854.38
# Name: fare, dtype: float64

# %%
#Get the sum of all the fares.
total_fares = pyber_data_df["fare"].sum()
total_fares
# Out:
# 63538.64

# %%
# Calculate the percentage of fare for each city type.
type_percentages = sum_fares_by_type /  total_fares * 100
type_percentages
# Out:
# type
# Rural        6.811493
# Suburban    30.463872
# Urban       62.724635
# Name: fare, dtype: float64

# %%
#Advance version
#Calculate the percentage of fare for each city type.
type_percents = pyber_data_df.groupby(["type"]).sum()["fare"] / pyber_data_df["fare"].sum() * 100
type_percents
# Out:
# type
# Rural        6.811493
# Suburban    30.463872
# Urban       62.724635
# Name: fare, dtype: float64

# %%
#5.5.2
#Build the percentage of fares by city type pie chart.
plt.pie(type_percents, labels=["Rural", "Suburban", "Urban"])
plt.show()

# %%
#Build the percentage of fares by city type pie chart.
plt.pie(type_percents,    
    labels=["Rural", "Suburban", "Urban"],
    colors=["gold", "lightskyblue", "lightcoral"],
    explode=[0, 0, 0.1],
    autopct='%1.1f%%',
    shadow=True, startangle=150)

#Add the title
plt.title("% of Total Fares by City")

#Show the chart
plt.show()

# %%
#Import mpl to change the plot configurations using rcParams.
import matplotlib as mpl

#Build the pie chart
plt.subplots(figsize=(10, 6))

plt.pie(type_percents,    
    labels=["Rural", "Suburban", "Urban"],
    colors=["gold", "lightskyblue", "lightcoral"],
    explode=[0, 0, 0.1],
    autopct='%1.1f%%',
    shadow=True, startangle=150)

#Add the title
plt.title("% of Total Fares by City")

#Change the default font size from 10 to 14
mpl.rcParams['font.size'] = 14

#Save figure
plt.savefig("analysis/Fig5.png")

#Show the chart
plt.show()

# %%
#5.6.1
pyber_data_df.head()
# Out:
#                  city                 date   fare        ride_id  \
# 0  Lake Jonathanshire  2019-01-14 10:14:22  13.83  5739410935873
# 1  South Michelleport  2019-03-04 18:24:09  30.24  2343912425577
# 2  Port Samanthamouth  2019-02-24 04:29:00  33.44  2005065760003
# 3          Rodneyfort  2019-02-10 23:22:03  23.44  5149245426178
# 4          South Jack  2019-03-06 04:28:35  34.58  3908451377344
#
#    driver_count   type
# 0             5  Urban
# 1            72  Urban
# 2            57  Urban
# 3            34  Urban
# 4            46  Urban

# %%
#Create a pie chart for the percentage of total rides by city type

#ride_count = pyber_data_df.groupby(["type"]).count()["ride_id"]
#ride_count

#ride_count_total = (pyber_data_df.groupby(["type"]).count()["ride_id"]).sum()
#ride_count_total

#1. Calculate the percentage of total rides by city type
ride_percents = pyber_data_df.groupby(["type"]).count()["ride_id"] / (pyber_data_df.groupby(["type"]).count()["ride_id"]).sum() *100
ride_percents
# Out:
# type
# Rural        5.263158
# Suburban    26.315789
# Urban       68.421053
# Name: ride_id, dtype: float64

# %%
#2. Import mpl to change the plot configurations using rcParams and create the pie chart
import matplotlib as mpl

#Build the pie chart
plt.subplots(figsize=(10, 6))

plt.pie(ride_percents,    
    labels=["Rural", "Suburban", "Urban"],
    colors=["gold", "lightskyblue", "lightcoral"],
    explode=[0, 0, 0.1],
    autopct='%1.1f%%',
    shadow=True, startangle=150)

#Add the title
plt.title("% of Total Rides by City")

#Change the default font size from 10 to 14
mpl.rcParams['font.size'] = 14

#Save figure
plt.savefig("analysis/Fig6.png")

#Show the chart
plt.show()

# %%
city_data_df.head()
# Out:
#            city  driver_count   type
# 0   Richardfort            38  Urban
# 1  Williamsstad            59  Urban
# 2   Port Angela            67  Urban
# 3    Rodneyfort            34  Urban
# 4   West Robert            39  Urban

# %%
#Create a pie chart for the percentage of total drivers by city type
#1. Calculate the percentage of total drivers by city type
driver_percents = city_data_df.groupby(["type"]).sum()["driver_count"] / city_data_df["driver_count"].sum() * 100
driver_percents
# Out:
# type
# Rural        2.623613
# Suburban    16.481668
# Urban       80.894719
# Name: driver_count, dtype: float64

# %%
#2. Import mpl to change the plot configurations using rcParams and create the pie chart
import matplotlib as mpl

#Build the pie chart
plt.subplots(figsize=(10, 6))

plt.pie(driver_percents,    
    labels=["Rural", "Suburban", "Urban"],
    colors=["gold", "lightskyblue", "lightcoral"],
    explode=[0, 0, 0.1],
    autopct='%1.1f%%',
    shadow=True, startangle=150)

#Add the title
plt.title("% of Total Driver Counts by City")

#Change the default font size from 10 to 14
mpl.rcParams['font.size'] = 14

#Save figure
plt.savefig("analysis/Fig7.png")

#Show the chart
plt.show()
